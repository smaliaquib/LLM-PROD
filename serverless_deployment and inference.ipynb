# %%
# !gcloud container clusters get-credentials cluster-2 --zone us-central1-c --project automated-lore-454117-q5
# Out:
# Fetching cluster endpoint and auth data.
# kubeconfig entry generated for cluster-2.

# %%
# !bash deploy-kserve.sh
# Out:
# Installing Knative Serving CRDs...
# customresourcedefinition.apiextensions.k8s.io/certificates.networking.internal.knative.dev created
# customresourcedefinition.apiextensions.k8s.io/configurations.serving.knative.dev created
# customresourcedefinition.apiextensions.k8s.io/clusterdomainclaims.networking.internal.knative.dev created
# customresourcedefinition.apiextensions.k8s.io/domainmappings.serving.knative.dev created
# customresourcedefinition.apiextensions.k8s.io/ingresses.networking.internal.knative.dev created
# customresourcedefinition.apiextensions.k8s.io/metrics.autoscaling.internal.knative.dev created
# customresourcedefinition.apiextensions.k8s.io/podautoscalers.autoscaling.internal.knative.dev created
# customresourcedefinition.apiextensions.k8s.io/revisions.serving.knative.dev created
# customresourcedefinition.apiextensions.k8s.io/routes.serving.knative.dev created
# ...

# %%
# !python load-test-new.py --concurrent 200 --total 1000
# Out:
# Starting asynchronous load test with 200 concurrent requests, 1000 total requests
# Request 80 completed - Status: 200, Time: 5.1872s
# Request 100 completed - Status: 500, Time: 5.2817s
# Request 140 completed - Status: 500, Time: 5.5345s
# Request 200 completed - Status: 200, Time: 5.5785s
# Request 180 completed - Status: 200, Time: 5.6276s
# Request 120 completed - Status: 200, Time: 5.7168s
# Request 160 completed - Status: 200, Time: 5.7453s
# Request 20 completed - Status: 500, Time: 5.8125s
# Request 40 completed - Status: 200, Time: 6.1368s
# Request 60 completed - Status: 200, Time: 6.2667s
# Request 280 completed - Status: 200, Time: 3.8951s
# Request 320 completed - Status: 500, Time: 3.9892s
# Request 220 completed - Status: 200, Time: 4.0305s
# Request 340 completed - Status: 200, Time: 4.1516s
# Request 380 completed - Status: 200, Time: 4.2268s
# Request 360 completed - Status: 200, Time: 4.2342s
# Request 400 completed - Status: 500, Time: 4.3113s
# ...

# %% [markdown]
# You can see how it is getting auto scaled

# %% [markdown]
# <img src="img/scaling.png" width="500" alt="Image title">
